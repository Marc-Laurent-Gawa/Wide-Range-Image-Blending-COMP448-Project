# %% [markdown]
# <a href="https://colab.research.google.com/github/Marc-Laurent-Gawa/Wide-Range-Image-Blending-COMP448-Project/blob/main/External_dataset_running.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Runing first training Phase

# %%
# !pip install torch torchvision tensorboard tensorboardX
# !git clone https://github.com/Marc-Laurent-Gawa/Wide-Range-Image-Blending-COMP448-Project.git
# %cd Wide-Range-Image-Blending-COMP448-Project
# !pip install gdown
# !mkdir -p weights
# !gdown --id 1q4S4mepJ60ba6HmGWMg9XdqT3mMgv5Oa -O weights/
# !gdown --id 1wnEsnVbsTY5Vz9FyCjGDm_RSYMYVMbig -O weights/
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 7.5 MB/s eta 0:00:00
# ...
# Cloning into 'Wide-Range-Image-Blendi-COMP448-Projectng'...
# remote: Enumerating objects: 137, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 137 (delta 9), reused 69 (delta 8), pack-reused 62 (from 1)
# Receiving objects: 100% (137/137), 32.13 MiB | 16.31 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# /content/Wide-Range-Image-Blendi-COMP448-Projectng
# ...
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1q4S4mepJ60ba6HmGWMg9XdqT3mMgv5Oa
# To: /content/Wide-Range-Image-Blendi-COMP448-Projectng/weights/Dis
# 100% 12.6M/12.6M [00:00<00:00, 28.8MB/s]
# ...

# %%
# !gdown --id 1vCgH_8Cl-EqfalVLyDmx04ZrxzhtJJj0 -O /content/CVRG-Pano.zip
# !unzip -q /content/CVRG-Pano.zip -d /content/CVRG-Pano
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1vCgH_8Cl-EqfalVLyDmx04ZrxzhtJJj0
# From (redirected): https://drive.google.com/uc?id=1vCgH_8Cl-EqfalVLyDmx04ZrxzhtJJj0&confirm=t&uuid=1f95684e-24c9-4f23-992f-4bd293c7a1b7
# To: /content/CVRG-Pano.zip
# 100% 946M/946M [00:18<00:00, 50.3MB/s]

# %%
# !python train_SR.py --train_data_dir /content/CVRG-Pano/CVRG-Pano/train/rgb

# %% [markdown]
# Use this block to directly send the latest weights to your drive as downloading from colab directly is incredibly slow

# %%
from google.colab import drive
import shutil
import os

drive.mount('/content/drive') #Runs in case your drive has not been mounted

src_path = '/content/Wide-Range-Image-Blending-COMP448-Project/checkpoints/SR_Stage/Dis_200'
dst_dir = '/content/drive/MyDrive/WideRangeBackups'
os.makedirs(dst_dir, exist_ok=True)

shutil.copy(src_path, dst_dir)

print(f"Checkpoint copied to Google Drive: {dst_dir}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Checkpoint copied to Google Drive: /content/drive/MyDrive/WideRangeBackups

# %% [markdown]
# # Running second training phase

# %% [markdown]
# The codes are written in a way to assume a reset of Code environment to be able to be run without having to do both training phases in one go

# %%
# !pip install torch torchvision tensorboard tensorboardX
# !git clone https://github.com/Marc-Laurent-Gawa/Wide-Range-Image-Blending-COMP448-Project.git
# %cd Wide-Range-Image-Blending-COMP448-Project
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 10.0 MB/s eta 0:00:00
# ...
# Cloning into 'Wide-Range-Image-Blending-COMP448-Project'...
# remote: Enumerating objects: 173, done.
# remote: Counting objects: 100% (111/111), done.
# remote: Compressing objects: 100% (93/93), done.
# remote: Total 173 (delta 27), reused 89 (delta 15), pack-reused 62 (from 1)
# Receiving objects: 100% (173/173), 32.15 MiB | 14.39 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# /content/Wide-Range-Image-Blending-COMP448-Project

# %%
# !pip install gdown
# !mkdir -p weights
# !gdown --id 1SrWsIFU9c4F0_MQ7T1Gl2HmCSw60TCGz -O weights/Dis
#https://drive.google.com/file/d/1SrWsIFU9c4F0_MQ7T1Gl2HmCSw60TCGz/view?usp=sharing
# !gdown --id 1HbnByVwDl9jgQ8mCSL3fE1121hCHNkiz -O weights/Gen
#https://drive.google.com/file/d/1HbnByVwDl9jgQ8mCSL3fE1121hCHNkiz/view?usp=sharing
# !gdown --id 1vCgH_8Cl-EqfalVLyDmx04ZrxzhtJJj0 -O /content/CVRG-Pano.zip
# !unzip -q /content/CVRG-Pano.zip -d /content/CVRG-Pano
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1SrWsIFU9c4F0_MQ7T1Gl2HmCSw60TCGz
# To: /content/Wide-Range-Image-Blending-COMP448-Project/weights/Dis
# 100% 12.6M/12.6M [00:00<00:00, 178MB/s]
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1HbnByVwDl9jgQ8mCSL3fE1121hCHNkiz
# From (redirected): https://drive.google.com/uc?id=1HbnByVwDl9jgQ8mCSL3fE1121hCHNkiz&confirm=t&uuid=f6022fde-a1f9-4673-9d9d-df320c97dbc9
# To: /content/Wide-Range-Image-Blending-COMP448-Project/weights/Gen
# ...

# %%
# !python train_FT.py --load_pretrain True --train_data_dir /content/CVRG-Pano/CVRG-Pano/train/rgb --rand_pair True --epoch 146
# Out:
# Initializing model...
# Loading model weight...
# Loading data...
# train data: 524 images, 1572 pairs
# /usr/local/lib/python3.12/dist-packages/torch/optim/lr_scheduler.py:192: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# ...

# %%
from google.colab import drive
import shutil
import os

drive.mount('/content/drive') #Runs in case your drive has not been mounted

src_path = '/content/Wide-Range-Image-Blending-COMP448-Project/checkpoints/FT_Stage/Gen_146'
dst_dir = '/content/drive/MyDrive/WideRangeBackups_FT'
os.makedirs(dst_dir, exist_ok=True)

shutil.copy(src_path, dst_dir)

print(f"Checkpoint copied to Google Drive: {dst_dir}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Checkpoint copied to Google Drive: /content/drive/MyDrive/WideRangeBackups_FT
